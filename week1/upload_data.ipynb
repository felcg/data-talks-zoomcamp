# %%
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 10.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.21.0 in /usr/lib/python3/dist-packages (from pandas) (1.21.5)
# Collecting python-dateutil>=2.8.2
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 KB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, python-dateutil, pandas
# Successfully installed pandas-2.0.1 python-dateutil-2.8.2 tzdata-2023.3

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.1'

# %%
# %pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in /home/budehux/.local/lib/python3.10/site-packages (12.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/lib/python3/dist-packages (from pyarrow) (1.21.5)

# %%
df = pd.read_parquet('/home/budehux/Projects/DataEngineeringZoomcamp/week1/yellow_tripdata_2021-01.parquet')
df.to_csv('yellow_tripdata_2021-01.csv')

# %%
df = df.to_csv('yellow_tripdata_2021-01.csv')

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)

# %%
df
# Out:
#     Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime
# 0            0         1  2021-01-01 00:30:10   2021-01-01 00:36:12  \
# 1            1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2            2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3            3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4            4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ..         ...       ...                  ...                   ...
# 95          95         2  2021-01-01 00:12:41   2021-01-01 00:26:47
# 96          96         2  2021-01-01 00:23:29   2021-01-01 00:35:03
# 97          97         2  2021-01-01 00:46:17   2021-01-01 00:54:25
# 98          98         2  2021-01-01 00:28:16   2021-01-01 00:51:44
# 99          99         2  2021-01-01 00:42:35   2021-01-01 00:54:41
#
#     passenger_count  trip_distance  RatecodeID store_and_fwd_flag
# 0               1.0           2.10         1.0                  N  \
# 1               1.0           0.20         1.0                  N
# 2               1.0          14.70         1.0                  N
# 3               0.0          10.60         1.0                  N
# 4               1.0           4.94         1.0                  N
# ..              ...            ...         ...                ...
# 95              1.0           4.13         1.0                  N
# 96              2.0           4.12         1.0                  N
# 97              2.0           2.22         1.0                  N
# 98              1.0           7.11         1.0                  N
# 99              3.0           1.61         1.0                  N
#
#     PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax
# 0            142            43             2          8.0    3.0      0.5  \
# 1            238           151             2          3.0    0.5      0.5
# 2            132           165             1         42.0    0.5      0.5
# 3            138           132             1         29.0    0.5      0.5
# 4             68            33             1         16.5    0.5      0.5
# ..           ...           ...           ...          ...    ...      ...
# 95           161           226             1         14.5    0.5      0.5
# 96           162            74             2         13.5    0.5      0.5
# 97           144           170             1          9.0    0.5      0.5
# 98           264           264             2         23.5    0.5      0.5
# 99           229           237             2          9.5    0.5      0.5
#
#     tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0         0.00           0.0                    0.3         11.80  \
# 1         0.00           0.0                    0.3          4.30
# 2         8.65           0.0                    0.3         51.95
# 3         6.05           0.0                    0.3         36.35
# 4         4.06           0.0                    0.3         24.36
# ..         ...           ...                    ...           ...
# 95        3.66           0.0                    0.3         21.96
# 96        0.00           0.0                    0.3         17.30
# 97        2.56           0.0                    0.3         15.36
# 98        0.00           0.0                    0.3         24.80
# 99        0.00           0.0                    0.3         13.30
#
#     congestion_surcharge  airport_fee
# 0                    2.5          NaN
# 1                    0.0          NaN
# 2                    0.0          NaN
# 3                    0.0          NaN
# 4                    2.5          NaN
# ..                   ...          ...
# 95                   2.5          NaN
# 96                   2.5          NaN
# 97                   2.5          NaN
# 98                   0.0          NaN
# 99                   2.5          NaN
#
# [100 rows x 20 columns]

# %%
pd.io.sql.get_schema(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_45532/2515506838.py in <module>
# ----> 1 pd.io.sql.get_schema(df)
#
# TypeError: get_schema() missing 1 required positional argument: 'name'

# %%
pd.io.sql.get_schema(df, name="yellow_taxi_data")
# Out:
# 'CREATE TABLE "yellow_taxi_data" (\n"Unnamed: 0" INTEGER,\n  "VendorID" INTEGER,\n  "tpep_pickup_datetime" TEXT,\n  "tpep_dropoff_datetime" TEXT,\n  "passenger_count" REAL,\n  "trip_distance" REAL,\n  "RatecodeID" REAL,\n  "store_and_fwd_flag" TEXT,\n  "PULocationID" INTEGER,\n  "DOLocationID" INTEGER,\n  "payment_type" INTEGER,\n  "fare_amount" REAL,\n  "extra" REAL,\n  "mta_tax" REAL,\n  "tip_amount" REAL,\n  "tolls_amount" REAL,\n  "improvement_surcharge" REAL,\n  "total_amount" REAL,\n  "congestion_surcharge" REAL,\n  "airport_fee" REAL\n)'

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "Unnamed: 0" INTEGER,
#   "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
pd.to_datetime(df.tpep_pickup_datetime)
# Out:
# 0    2021-01-01 00:30:10
# 1    2021-01-01 00:51:20
# 2    2021-01-01 00:43:30
# 3    2021-01-01 00:15:48
# 4    2021-01-01 00:31:49
#              ...
# 95   2021-01-01 00:12:41
# 96   2021-01-01 00:23:29
# 97   2021-01-01 00:46:17
# 98   2021-01-01 00:28:16
# 99   2021-01-01 00:42:35
# Name: tpep_pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
pd.to_datetime(df.tpep_dropoff_datetime)
# Out:
# 0    2021-01-01 00:36:12
# 1    2021-01-01 00:52:19
# 2    2021-01-01 01:11:06
# 3    2021-01-01 00:31:01
# 4    2021-01-01 00:48:21
#              ...
# 95   2021-01-01 00:26:47
# 96   2021-01-01 00:35:03
# 97   2021-01-01 00:54:25
# 98   2021-01-01 00:51:44
# 99   2021-01-01 00:54:41
# Name: tpep_dropoff_datetime, Length: 100, dtype: datetime64[ns]

# %%
pd.to_datetime(df.tpep_pickup_datetime)
# Out:
# 0    2021-01-01 00:30:10
# 1    2021-01-01 00:51:20
# 2    2021-01-01 00:43:30
# 3    2021-01-01 00:15:48
# 4    2021-01-01 00:31:49
#              ...
# 95   2021-01-01 00:12:41
# 96   2021-01-01 00:23:29
# 97   2021-01-01 00:46:17
# 98   2021-01-01 00:28:16
# 99   2021-01-01 00:42:35
# Name: tpep_pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"Unnamed: 0" BIGINT,
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime
# 0           0         1  2021-01-01 00:30:10   2021-01-01 00:36:12  \
# 1           1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2           2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3           3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4           4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag
# 0              1.0           2.10         1.0                  N  \
# 1              1.0           0.20         1.0                  N
# 2              1.0          14.70         1.0                  N
# 3              0.0          10.60         1.0                  N
# 4              1.0           4.94         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax
# 0           142            43             2          8.0    3.0      0.5  \
# 1           238           151             2          3.0    0.5      0.5
# 2           132           165             1         42.0    0.5      0.5
# 3           138           132             1         29.0    0.5      0.5
# 4            68            33             1         16.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0        0.00           0.0                    0.3         11.80  \
# 1        0.00           0.0                    0.3          4.30
# 2        8.65           0.0                    0.3         51.95
# 3        6.05           0.0                    0.3         36.35
# 4        4.06           0.0                    0.3         24.36
#
#    congestion_surcharge  airport_fee
# 0                   2.5          NaN
# 1                   0.0          NaN
# 2                   0.0          NaN
# 3                   0.0          NaN
# 4                   2.5          NaN

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _exec_insertmany_context(self, dialect, context)
#    2107                 else:
# -> 2108                     dialect.do_execute(
#    2109                         cursor,
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     919     def do_execute(self, cursor, statement, parameters, context=None):
# --> 920         cursor.execute(statement, parameters)
#     921
#
# UndefinedColumn: column "Unnamed: 0" of relation "yellow_taxi_data" does not exist
# LINE 1: INSERT INTO yellow_taxi_data (index, "Unnamed: 0", "VendorID...
#                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2876         from pandas.io import sql
#    2877
# -> 2878         return sql.to_sql(
#    2879             self,
#    2880             name,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     765
#     766     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 767         return pandas_sql.to_sql(
#     768             frame,
#     769             name,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1916         )
#    1917
# -> 1918         total_inserted = sql_engine.insert_records(
#    1919             table=table,
#    1920             con=self.con,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1466             if re.search(msg, err_text):
#    1467                 raise ValueError("inf cannot be used with MySQL") from err
# -> 1468             raise err
#    1469
#    1470
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1457
#    1458         try:
# -> 1459             return table.insert(chunksize=chunksize, method=method)
#    1460         except exc.StatementError as err:
#    1461             # GH34431
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#    1019
#    1020                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1021                 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1022                 # GH 46891
#    1023                 if is_integer(num_inserted):
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     925         """
#     926         data = [dict(zip(keys, row)) for row in data_iter]
# --> 927         result = conn.execute(self.table.insert(), data)
#     928         return result.rowcount
#     929
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1411             raise exc.ObjectNotExecutableError(statement) from err
#    1412         else:
# -> 1413             return meth(
#    1414                 self,
#    1415                 distilled_parameters,
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, distilled_params, execution_options)
#     481             if TYPE_CHECKING:
#     482                 assert isinstance(self, Executable)
# --> 483             return connection._execute_clauseelement(
#     484                 self, distilled_params, execution_options
#     485             )
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1635             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1636         )
# -> 1637         ret = self._execute_context(
#    1638             dialect,
#    1639             dialect.execution_ctx_cls._init_compiled,
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1834
#    1835         if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1836             return self._exec_insertmany_context(
#    1837                 dialect,
#    1838                 context,
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _exec_insertmany_context(self, dialect, context)
#    2114
#    2115             except BaseException as e:
# -> 2116                 self._handle_dbapi_exception(
#    2117                     e,
#    2118                     sql_util._long_statement(sub_stmt),
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337             elif should_wrap:
#    2338                 assert sqlalchemy_exception is not None
# -> 2339                 raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340             else:
#    2341                 assert exc_info[1] is not None
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _exec_insertmany_context(self, dialect, context)
#    2106                         break
#    2107                 else:
# -> 2108                     dialect.do_execute(
#    2109                         cursor,
#    2110                         sub_stmt,
#
# ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     918
#     919     def do_execute(self, cursor, statement, parameters, context=None):
# --> 920         cursor.execute(statement, parameters)
#     921
#     922     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Unnamed: 0" of relation "yellow_taxi_data" does not exist
# LINE 1: INSERT INTO yellow_taxi_data (index, "Unnamed: 0", "VendorID...
#                                              ^
#
# [SQL: INSERT INTO yellow_taxi_data (index, "Unnamed: 0", "VendorID", tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, "RatecodeID", store_and_fwd_flag, "PULocationID", "DOLocationID", payment_type, fare_amount, extra, mta_tax, t ... 495692 characters truncated ... vement_surcharge__999)s, %(total_amount__999)s, %(congestion_surcharge__999)s, %(airport_fee__999)s)]
# [parameters: {'index__0': 0, 'tip_amount__0': 0.0, 'PULocationID__0': 142, 'fare_amount__0': 8.0, 'store_and_fwd_flag__0': 'N', 'extra__0': 3.0, 'VendorID__0': 1, 'DOLocationID__0': 43, 'tolls_amount__0': 0.0, 'trip_distance__0': 2.1, 'congestion_surcharge__0': 2.5, 'improvement_surcharge__0': 0.3, 'airport_fee__0': None, 'UnnamedC_0__0': 0, 'payment_type__0': 2, 'passenger_count__0': 1.0, 'RatecodeID__0': 1.0, 'tpep_dropoff_datetime__0': datetime.datetime(2021, 1, 1, 0, 36, 12), 'tpep_pickup_datetime__0': datetime.datetime(2021, 1, 1, 0, 30, 10), 'total_amount__0': 11.8, 'mta_tax__0': 0.5, 'index__1': 1, 'tip_amount__1': 0.0, 'PULocationID__1': 238, 'fare_amount__1': 3.0, 'store_and_fwd_flag__1': 'N', 'extra__1': 0.5, 'VendorID__1': 1, 'DOLocationID__1': 151, 'tolls_amount__1': 0.0, 'trip_distance__1': 0.2, 'congestion_surcharge__1': 0.0, 'improvement_surcharge__1': 0.3, 'airport_fee__1': None, 'UnnamedC_0__1': 1, 'payment_type__1': 2, 'passenger_count__1': 1.0, 'RatecodeID__1': 1.0, 'tpep_dropoff_datetime__1': datetime.datetime(2021, 1, 1, 0, 52, 19), 'tpep_pickup_datetime__1': datetime.datetime(2021, 1, 1, 0, 51, 20), 'total_amount__1': 4.3, 'mta_tax__1': 0.5, 'index__2': 2, 'tip_amount__2': 8.65, 'PULocationID__2': 132, 'fare_amount__2': 42.0, 'store_and_fwd_flag__2': 'N', 'extra__2': 0.5, 'VendorID__2': 1, 'DOLocationID__2': 165 ... 20900 parameters truncated ... 'UnnamedC_0__997': 997, 'payment_type__997': 1, 'passenger_count__997': 3.0, 'RatecodeID__997': 1.0, 'tpep_dropoff_datetime__997': datetime.datetime(2021, 1, 1, 0, 24, 23), 'tpep_pickup_datetime__997': datetime.datetime(2021, 1, 1, 0, 16, 38), 'total_amount__997': 14.76, 'mta_tax__997': 0.5, 'index__998': 998, 'tip_amount__998': 0.0, 'PULocationID__998': 263, 'fare_amount__998': -12.0, 'store_and_fwd_flag__998': 'N', 'extra__998': -0.5, 'VendorID__998': 2, 'DOLocationID__998': 186, 'tolls_amount__998': 0.0, 'trip_distance__998': 3.35, 'congestion_surcharge__998': -2.5, 'improvement_surcharge__998': -0.3, 'airport_fee__998': None, 'UnnamedC_0__998': 998, 'payment_type__998': 4, 'passenger_count__998': 1.0, 'RatecodeID__998': 1.0, 'tpep_dropoff_datetime__998': datetime.datetime(2021, 1, 1, 0, 40, 8), 'tpep_pickup_datetime__998': datetime.datetime(2021, 1, 1, 0, 28, 9), 'total_amount__998': -15.8, 'mta_tax__998': -0.5, 'index__999': 999, 'tip_amount__999': 0.0, 'PULocationID__999': 263, 'fare_amount__999': 12.0, 'store_and_fwd_flag__999': 'N', 'extra__999': 0.5, 'VendorID__999': 2, 'DOLocationID__999': 186, 'tolls_amount__999': 0.0, 'trip_distance__999': 3.35, 'congestion_surcharge__999': 2.5, 'improvement_surcharge__999': 0.3, 'airport_fee__999': None, 'UnnamedC_0__999': 999, 'payment_type__999': 2, 'passenger_count__999': 1.0, 'RatecodeID__999': 1.0, 'tpep_dropoff_datetime__999': datetime.datetime(2021, 1, 1, 0, 40, 8), 'tpep_pickup_datetime__999': datetime.datetime(2021, 1, 1, 0, 28, 9), 'total_amount__999': 15.8, 'mta_tax__999': 0.5}]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime
# 0           0         1  2021-01-01 00:30:10   2021-01-01 00:36:12  \
# 1           1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2           2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3           3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4           4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag
# 0              1.0           2.10         1.0                  N  \
# 1              1.0           0.20         1.0                  N
# 2              1.0          14.70         1.0                  N
# 3              0.0          10.60         1.0                  N
# 4              1.0           4.94         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax
# 0           142            43             2          8.0    3.0      0.5  \
# 1           238           151             2          3.0    0.5      0.5
# 2           132           165             1         42.0    0.5      0.5
# 3           138           132             1         29.0    0.5      0.5
# 4            68            33             1         16.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0        0.00           0.0                    0.3         11.80  \
# 1        0.00           0.0                    0.3          4.30
# 2        8.65           0.0                    0.3         51.95
# 3        6.05           0.0                    0.3         36.35
# 4        4.06           0.0                    0.3         24.36
#
#    congestion_surcharge  airport_fee
# 0                   2.5          NaN
# 1                   0.0          NaN
# 2                   0.0          NaN
# 3                   0.0          NaN
# 4                   2.5          NaN

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime
# 0           0         1  2021-01-01 00:30:10   2021-01-01 00:36:12  \
# 1           1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2           2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3           3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4           4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag
# 0              1.0           2.10         1.0                  N  \
# 1              1.0           0.20         1.0                  N
# 2              1.0          14.70         1.0                  N
# 3              0.0          10.60         1.0                  N
# 4              1.0           4.94         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax
# 0           142            43             2          8.0    3.0      0.5  \
# 1           238           151             2          3.0    0.5      0.5
# 2           132           165             1         42.0    0.5      0.5
# 3           138           132             1         29.0    0.5      0.5
# 4            68            33             1         16.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0        0.00           0.0                    0.3         11.80  \
# 1        0.00           0.0                    0.3          4.30
# 2        8.65           0.0                    0.3         51.95
# 3        6.05           0.0                    0.3         36.35
# 4        4.06           0.0                    0.3         24.36
#
#    congestion_surcharge  airport_fee
# 0                   2.5          NaN
# 1                   0.0          NaN
# 2                   0.0          NaN
# 3                   0.0          NaN
# 4                   2.5          NaN

# %%
df_iter = pd.read_csv('cut_yellow_tripdata.csv', iterator=True, chunksize=100000)

# %%
df = nex(df_iter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_45532/3096076007.py in <module>
# ----> 1 df = nex(df_iter)
#
# NameError: name 'nex' is not defined

# %%
df = next(df_iter)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0  \
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID
# 0           2.10         1.0                  N           142            43  \
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount
# 0             2          8.0    3.0      0.5        0.00           0.0  \
# 1             2          3.0    0.5      0.5        0.00           0.0
# 2             1         42.0    0.5      0.5        8.65           0.0
# 3             1         29.0    0.5      0.5        6.05           0.0
# 4             1         16.5    0.5      0.5        4.06           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.3         11.80                   2.5          NaN
# 1                    0.3          4.30                   0.0          NaN
# 2                    0.3         51.95                   0.0          NaN
# 3                    0.3         36.35                   0.0          NaN
# 4                    0.3         24.36                   2.5          NaN

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    print('inserted another chunk... took %.3f seconds' %(t_end - t_start))
# Out:
# inserted another chunk... took 8.697 seconds
# inserted another chunk... took 8.898 seconds
# inserted another chunk... took 8.766 seconds
# inserted another chunk... took 8.797 seconds
# inserted another chunk... took 8.940 seconds
# inserted another chunk... took 9.571 seconds
# /tmp/ipykernel_45532/1546534849.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
# inserted another chunk... took 9.289 seconds
# inserted another chunk... took 8.569 seconds
# inserted another chunk... took 7.997 seconds
# inserted another chunk... took 8.642 seconds
# inserted another chunk... took 8.854 seconds
# /tmp/ipykernel_45532/1546534849.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk... took 8.722 seconds
# inserted another chunk... took 5.805 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_45532/1546534849.py in <module>
#       1 while True:
#       2     t_start = time()
# ----> 3     df = next(df_iter)
#       4     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       5     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in __next__(self)
#    1622     def __next__(self) -> DataFrame:
#    1623         try:
# -> 1624             return self.get_chunk()
#    1625         except StopIteration:
#    1626             self.close()
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1731                 raise StopIteration
#    1732             size = min(size, self.nrows - self._currow)
# -> 1733         return self.read(nrows=size)
#    1734
#    1735     def __enter__(self) -> TextFileReader:
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
